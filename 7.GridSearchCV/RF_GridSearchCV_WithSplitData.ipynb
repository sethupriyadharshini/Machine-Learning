# %%
import pandas as pd #import pandas library to handle file, database

# %%
dataset = pd.read_csv("insurance_pre.csv") #read the file data and store it in dataset variable

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#data preprocessing - because categorial data can't be handle so we modify the data into numerical data using one hot encoding(Nominal)
dataset = pd.get_dummies(dataset, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
boolean_columns = dataset.select_dtypes(include=['bool']).columns #get boolean type column data from the dataset and store it in boolean_columns variable
print(boolean_columns)

dataset[boolean_columns] = dataset[boolean_columns].astype(int) #convert boolean column dataset to 0's and 1's
print(dataset[boolean_columns])
# Out:
# Index(['sex_male', 'smoker_yes'], dtype='object')
#       sex_male  smoker_yes
# 0            0           1
# 1            1           0
# 2            1           0
# 3            1           0
# 4            1           0
# ...        ...         ...
# 1333         1           0
# 1334         0           0
# 1335         0           0
# 1336         0           0
# 1337         0           1
#
# [1338 rows x 2 columns]

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#split input data
independent = dataset [['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset [['charges']] #split output data

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split #split the training and testing dataset

X_train,X_test,y_train,y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Get mean and standard deviation
mean_values = sc.mean_  # Mean of the features
std_values = sc.scale_  # Standard deviation of the features

print("Mean:", mean_values)
print("Standard Deviation:", std_values)
# Out:
# Mean: [39.47115385 30.75236645  1.08119658  0.48824786  0.20299145]
# Standard Deviation: [14.0050823   6.23225555  1.20355113  0.49986187  0.40222621]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor #Create a model from training set

param_grid = {'criterion' : ['squared_error','friedman_mse','absolute_error','poisson'], 'n_estimators' : [10,50,100]
             , 'max_features' : [None,'sqrt']}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1, scoring='r2')

grid.fit(X_train, y_train)

#grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\sethu\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt'],
#                          'n_estimators': [10, 50, 100]},
#              scoring='r2', verbose=3)

# %%
re = grid.cv_results_

#print("CV_RESULTS : ", re)

grid_pred = grid.predict(X_test) #test the model with test data

from sklearn.metrics import r2_score #Evaluation metrics

r_score = r2_score(y_test, grid_pred)
print("R score value is : ", r_score) 

print("Best Score:", grid.best_score_)
print("Best Parameters:", grid.best_params_)
# Out:
# R score value is :  0.8704694166692487
# Best Score: 0.8129376631397267
# Best Parameters: {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
table = pd.DataFrame.from_dict(re) #convert dictonary format to DataFrame(table)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.067433      0.006048         0.005082        0.003463
# 1        0.300040      0.004825         0.014785        0.004211
# 2        0.612649      0.038888         0.023319        0.002692
# 3        0.041846      0.008159         0.002314        0.003055
# 4        0.242156      0.013481         0.016743        0.003253
# 5        0.452618      0.030139         0.019646        0.002786
# 6        0.069529      0.009156         0.007397        0.003916
# 7        0.322639      0.036706         0.012756        0.002596
# 8        0.580449      0.040558         0.020908        0.003613
# 9        0.059966      0.006827         0.007438        0.004409
# 10       0.232064      0.017485         0.009520        0.002339
# 11       0.485538      0.028262         0.019942        0.002075
# 12       0.237397      0.036054         0.004446        0.003027
# 13       1.164590      0.146541         0.012505        0.006365
# 14       2.151539      0.133539         0.022149        0.011376
# 15       0.152695      0.014571         0.005307        0.004383
# 16       0.664453      0.069189         0.009727        0.005356
# 17       1.284474      0.056919         0.021071        0.004621
# 18       0.081157      0.005751         0.004853        0.002880
# 19       0.416278      0.023462         0.008917        0.005075
# 20       0.806030      0.039396         0.020408        0.000158
# 21       0.072612      0.005799         0.005316        0.005184
# 22       0.346789      0.031388         0.012566        0.002739
# 23       0.631474      0.031426         0.015482        0.007177
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  10
# 1    squared_error               None                  50
# 2    squared_error               None                 100
# 3    squared_error               sqrt                  10
# 4    squared_error               sqrt                  50
# 5    squared_error               sqrt                 100
# 6     friedman_mse               None                  10
# 7     friedman_mse               None                  50
# 8     friedman_mse               None                 100
# 9     friedman_mse               sqrt                  10
# 10    friedman_mse               sqrt                  50
# 11    friedman_mse               sqrt                 100
# 12  absolute_error               None                  10
# 13  absolute_error               None                  50
# 14  absolute_error               None                 100
# 15  absolute_error               sqrt                  10
# 16  absolute_error               sqrt                  50
# 17  absolute_error               sqrt                 100
# 18         poisson               None                  10
# 19         poisson               None                  50
# 20         poisson               None                 100
# 21         poisson               sqrt                  10
# 22         poisson               sqrt                  50
# 23         poisson               sqrt                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.851943
# 1   {'criterion': 'squared_error', 'max_features':...           0.862849
# 2   {'criterion': 'squared_error', 'max_features':...           0.861154
# 3   {'criterion': 'squared_error', 'max_features':...           0.834044
# 4   {'criterion': 'squared_error', 'max_features':...           0.854652
# 5   {'criterion': 'squared_error', 'max_features':...           0.864114
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.853153
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.857594
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.861241
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.845523
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.858322
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.862744
# 12  {'criterion': 'absolute_error', 'max_features'...           0.836204
# 13  {'criterion': 'absolute_error', 'max_features'...           0.846337
# 14  {'criterion': 'absolute_error', 'max_features'...           0.851256
# 15  {'criterion': 'absolute_error', 'max_features'...           0.828349
# 16  {'criterion': 'absolute_error', 'max_features'...           0.852184
# 17  {'criterion': 'absolute_error', 'max_features'...           0.861989
# 18  {'criterion': 'poisson', 'max_features': None,...           0.854253
# 19  {'criterion': 'poisson', 'max_features': None,...           0.859823
# 20  {'criterion': 'poisson', 'max_features': None,...           0.866770
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.839737
# 22  {'criterion': 'poisson', 'max_features': 'sqrt...           0.854378
# 23  {'criterion': 'poisson', 'max_features': 'sqrt...           0.865823
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.764521           0.798578           0.794865
# 1            0.768146           0.812367           0.802213
# 2            0.761395           0.807115           0.800560
# 3            0.745590           0.770866           0.814734
# 4            0.791507           0.800909           0.824925
# 5            0.794739           0.808047           0.827176
# 6            0.735742           0.797179           0.788420
# 7            0.758652           0.817368           0.809155
# 8            0.761866           0.814033           0.798399
# 9            0.787236           0.809053           0.802063
# 10           0.784832           0.807672           0.824911
# 11           0.793922           0.809715           0.827907
# 12           0.772139           0.797832           0.793866
# 13           0.778031           0.796770           0.800682
# 14           0.785564           0.796733           0.790347
# 15           0.769780           0.790866           0.800842
# 16           0.775237           0.803436           0.827019
# 17           0.795101           0.804536           0.823363
# 18           0.747743           0.787650           0.800107
# 19           0.765600           0.809267           0.809018
# 20           0.768068           0.813001           0.803485
# 21           0.758079           0.792079           0.798625
# 22           0.786897           0.802637           0.825753
# 23           0.793243           0.812093           0.826376
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.761927         0.794367        0.032484               18
# 1            0.769840         0.803083        0.034596               10
# 2            0.767529         0.799551        0.035594               14
# 3            0.745309         0.782108        0.036266               24
# 4            0.774372         0.809273        0.027957                5
# 5            0.766214         0.812058        0.032729                3
# 6            0.760779         0.787054        0.039489               22
# 7            0.770884         0.802731        0.035278               11
# 8            0.767937         0.800695        0.035860               13
# 9            0.753224         0.799420        0.030026               15
# 10           0.760610         0.807269        0.033461                6
# 11           0.767011         0.812260        0.032198                2
# 12           0.751448         0.790298        0.028341               21
# 13           0.759616         0.796287        0.028992               17
# 14           0.763528         0.797486        0.029114               16
# 15           0.764438         0.790855        0.023011               20
# 16           0.764324         0.804440        0.032411                8
# 17           0.768585         0.810715        0.031132                4
# 18           0.773070         0.792565        0.035427               19
# 19           0.768921         0.802526        0.034244               12
# 20           0.770718         0.804408        0.035831                9
# 21           0.740703         0.785844        0.034396               23
# 22           0.763591         0.806651        0.031316                7
# 23           0.767154         0.812938        0.033052                1

# %% [raw]
# age = int(input("Enter the age:"))
# bmi = float(input("Enter the BMI:"))
# children = int(input("Enter the children number:"))
# sex = int(input("Enter sex (0 for female and 1 for male):"))
# smoker = int(input("Enter 0 for non smoker and 1 for smoker:"))

# %% [raw]
# Final_prediction =grid.predict([[age,bmi,children,sex,smoker]])
# print("Final_prediction of RF: {}".format(Final_prediction))

# %%
import pickle

fileName = "RF_Grid_WithSplitData_Insurance.sav"

pickle.dump(grid, open(fileName,'wb'))

# %%
load_model = pickle.load(open(fileName,'rb'))

result = load_model.predict([[30,25.899,2,1,1]])
result
# Out:
# array([46167.4599693])
