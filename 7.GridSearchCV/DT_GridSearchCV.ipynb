# %%
import pandas as pd #import pandas library to handle file, database

# %%
dataset = pd.read_csv("insurance_pre.csv") #read the file data and store it in dataset variable

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#data preprocessing - because categorial data can't be handle so we modify the data into numerical data using one hot encoding(Nominal)
dataset = pd.get_dummies(dataset, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
boolean_columns = dataset.select_dtypes(include=['bool']).columns #get boolean type column data from the dataset and store it in boolean_columns variable
print(boolean_columns)

dataset[boolean_columns] = dataset[boolean_columns].astype(int) #convert boolean column dataset to 0's and 1's
print(dataset[boolean_columns])
# Out:
# Index(['sex_male', 'smoker_yes'], dtype='object')
#       sex_male  smoker_yes
# 0            0           1
# 1            1           0
# 2            1           0
# 3            1           0
# 4            1           0
# ...        ...         ...
# 1333         1           0
# 1334         0           0
# 1335         0           0
# 1336         0           0
# 1337         0           1
#
# [1338 rows x 2 columns]

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#split input data
independent = dataset [['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset [['charges']] #split output data

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %% [raw]
# from sklearn.model_selection import train_test_split #split the training and testing dataset
#
# X_train,X_test,y_train,y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %% [raw]
# from sklearn.preprocessing import StandardScaler
#
# sc=StandardScaler()
# independent = sc.fit_transform(independent)
# dependent = sc.fit_transform(dependent)

# %% [raw]
# # Get mean and standard deviation
# mean_values = sc.mean_  # Mean of the features
# std_values = sc.scale_  # Standard deviation of the features
#
# print("Mean:", mean_values)
# print("Standard Deviation:", std_values)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor #Create a model

param_grid = {'criterion' : ['squared_error','friedman_mse','absolute_error','poisson'], 'splitter' : ['best','random']
             , 'max_features' : [None,'sqrt']}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1, scoring='r2')

#grid.fit(X_train, y_train)

grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt'],
#                          'splitter': ['best', 'random']},
#              scoring='r2', verbose=3)

# %%
re = grid.cv_results_

#print("CV_RESULTS : ", re)

grid_pred = grid.predict(independent) #test the model with input data

from sklearn.metrics import r2_score #Evaluation metrics

r_score = r2_score(dependent, grid_pred)
print("R score value is : ", r_score) 

print("Best Score:", grid.best_score_)
print("Best Parameters:", grid.best_params_)
# Out:
# R score value is :  0.998667156135576
# Best Score: 0.7093405606128359
# Best Parameters: {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}

# %%
table = pd.DataFrame.from_dict(re) #convert dictonary format to DataFrame(table)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.023133      0.005740         0.010933        0.006759
# 1        0.021828      0.010380         0.007988        0.006018
# 2        0.017431      0.008066         0.009612        0.003611
# 3        0.014949      0.005858         0.008897        0.005628
# 4        0.015248      0.004708         0.004479        0.002610
# 5        0.009848      0.003409         0.010512        0.001947
# 6        0.013453      0.003890         0.005793        0.002871
# 7        0.016269      0.010814         0.011486        0.003824
# 8        0.083207      0.019014         0.007402        0.004065
# 9        0.058523      0.005801         0.003809        0.003867
# 10       0.044508      0.008412         0.007250        0.004466
# 11       0.036129      0.013420         0.007557        0.002663
# 12       0.026861      0.011626         0.004094        0.004049
# 13       0.016765      0.008883         0.010478        0.004140
# 14       0.018751      0.011500         0.009123        0.005362
# 15       0.009607      0.002647         0.004097        0.003948
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4     friedman_mse               None           best
# 5     friedman_mse               None         random
# 6     friedman_mse               sqrt           best
# 7     friedman_mse               sqrt         random
# 8   absolute_error               None           best
# 9   absolute_error               None         random
# 10  absolute_error               sqrt           best
# 11  absolute_error               sqrt         random
# 12         poisson               None           best
# 13         poisson               None         random
# 14         poisson               sqrt           best
# 15         poisson               sqrt         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.725038
# 1   {'criterion': 'squared_error', 'max_features':...           0.678822
# 2   {'criterion': 'squared_error', 'max_features':...           0.734932
# 3   {'criterion': 'squared_error', 'max_features':...           0.743532
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.720725
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.677931
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.597275
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.636210
# 8   {'criterion': 'absolute_error', 'max_features'...           0.743261
# 9   {'criterion': 'absolute_error', 'max_features'...           0.703209
# 10  {'criterion': 'absolute_error', 'max_features'...           0.610887
# 11  {'criterion': 'absolute_error', 'max_features'...           0.733695
# 12  {'criterion': 'poisson', 'max_features': None,...           0.753125
# 13  {'criterion': 'poisson', 'max_features': None,...           0.706706
# 14  {'criterion': 'poisson', 'max_features': 'sqrt...           0.610424
# 15  {'criterion': 'poisson', 'max_features': 'sqrt...           0.679213
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.657537           0.715526           0.693345
# 1            0.549057           0.695683           0.703250
# 2            0.560520           0.756006           0.682249
# 3            0.502015           0.712094           0.668956
# 4            0.651143           0.730525           0.708997
# 5            0.634059           0.636454           0.720737
# 6            0.586649           0.704431           0.774839
# 7            0.547983           0.571684           0.587901
# 8            0.587522           0.717544           0.723097
# 9            0.659247           0.711710           0.721512
# 10           0.565445           0.683575           0.731690
# 11           0.560846           0.611684           0.665390
# 12           0.649976           0.739190           0.721904
# 13           0.605592           0.773428           0.706439
# 14           0.648623           0.626629           0.652655
# 15           0.544176           0.691641           0.676439
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.658763         0.690042        0.028000                6
# 1            0.753527         0.676068        0.068210                8
# 2            0.737470         0.694235        0.071224                4
# 3            0.587398         0.642799        0.087775               12
# 4            0.675866         0.697451        0.029595                3
# 5            0.700913         0.674019        0.034436                9
# 6            0.468335         0.626306        0.105390               14
# 7            0.555089         0.579773        0.031421               16
# 8            0.747081         0.703701        0.059182                2
# 9            0.674884         0.694113        0.023360                5
# 10           0.685124         0.655344        0.059280               11
# 11           0.625849         0.639493        0.057775               13
# 12           0.682508         0.709341        0.037974                1
# 13           0.633022         0.685038        0.059595                7
# 14           0.517411         0.611148        0.049303               15
# 15           0.690536         0.656401        0.056433               10

# %%
age = int(input("Enter the age:"))
bmi = float(input("Enter the BMI:"))
children = int(input("Enter the children number:"))
sex = int(input("Enter sex (0 for female and 1 for male):"))
smoker = int(input("Enter 0 for non smoker and 1 for smoker:"))
# Out:
# Enter the age: 26
# Enter the BMI: 20
# Enter the children number: 0
# Enter sex (0 for female and 1 for male): 0
# Enter 0 for non smoker and 1 for smoker: 1

# %%
Final_prediction =grid.predict([[age,bmi,children,sex,smoker]])
print("Final_prediction of DT: {}".format(Final_prediction))
# Out:
# Final_prediction of DT: [14571.8908]
# C:\Users\sethu\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle

fileName = "DT_Grid_Insurance.sav"

pickle.dump(grid, open(fileName,'wb'))

# %%
load_model = pickle.load(open(fileName,'rb'))

result = load_model.predict([[30,25.899,2,1,1]])
result
# Out:
# C:\Users\sethu\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([18972.495])
