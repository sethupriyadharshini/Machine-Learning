# %%
import pandas as pd #import pandas library to handle file, database

# %%
dataset = pd.read_csv("insurance_pre.csv") #read the file data and store it in dataset variable

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#data preprocessing - because categorial data can't be handle so we modify the data into numerical data using one hot encoding(Nominal)
dataset = pd.get_dummies(dataset, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
boolean_columns = dataset.select_dtypes(include=['bool']).columns #get boolean type column data from the dataset and store it in boolean_columns variable
print(boolean_columns)

dataset[boolean_columns] = dataset[boolean_columns].astype(int) #convert boolean column dataset to 0's and 1's
print(dataset[boolean_columns])
# Out:
# Index(['sex_male', 'smoker_yes'], dtype='object')
#       sex_male  smoker_yes
# 0            0           1
# 1            1           0
# 2            1           0
# 3            1           0
# 4            1           0
# ...        ...         ...
# 1333         1           0
# 1334         0           0
# 1335         0           0
# 1336         0           0
# 1337         0           1
#
# [1338 rows x 2 columns]

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
#split input data
independent = dataset [['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset [['charges']] #split output data

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split #split the training and testing dataset

X_train,X_test,y_train,y_test = train_test_split(independent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Get mean and standard deviation
mean_values = sc.mean_  # Mean of the features
std_values = sc.scale_  # Standard deviation of the features

print("Mean:", mean_values)
print("Standard Deviation:", std_values)
# Out:
# Mean: [39.47115385 30.75236645  1.08119658  0.48824786  0.20299145]
# Standard Deviation: [14.0050823   6.23225555  1.20355113  0.49986187  0.40222621]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor #Create a model from training set

param_grid = {'criterion' : ['squared_error','friedman_mse','absolute_error','poisson'], 'n_estimators' : [10,50,100]
             , 'max_features' : [None,'sqrt']}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1, scoring='r2')

grid.fit(X_train, y_train)

#grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\sethu\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt'],
#                          'n_estimators': [10, 50, 100]},
#              scoring='r2', verbose=3)

# %%
re = grid.cv_results_

#print("CV_RESULTS : ", re)

"""y_pred = grid.predict(X_test) #test the model with test data

from sklearn.metrics import r2_score #Evaluation metrics

r_score = r2_score(y_test, y_pred)
print("R score value is : ", r_score) """

print("Best Score:", grid.best_score_)
print("Best Parameters:", grid.best_params_)
# Out:
# Best Score: 0.8115882573743256
# Best Parameters: {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
table = pd.DataFrame.from_dict(re) #convert dictonary format to DataFrame(table)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.092995      0.022321         0.006001        0.003463
# 1        0.345861      0.023076         0.016219        0.008806
# 2        0.736943      0.157460         0.019960        0.005208
# 3        0.105442      0.044960         0.002597        0.002369
# 4        0.289148      0.054279         0.012146        0.002112
# 5        0.470520      0.052469         0.020755        0.001173
# 6        0.082887      0.024452         0.006789        0.003847
# 7        0.299448      0.009041         0.012481        0.002857
# 8        0.640706      0.080417         0.022206        0.009725
# 9        0.139242      0.124629         0.008259        0.004130
# 10       0.246517      0.024846         0.016745        0.009466
# 11       0.512646      0.074942         0.020141        0.000784
# 12       0.357682      0.195995         0.000000        0.000000
# 13       1.300594      0.127073         0.010715        0.003181
# 14       2.533430      0.118075         0.026116        0.012740
# 15       0.200666      0.040214         0.002590        0.003212
# 16       0.736769      0.085416         0.028112        0.022220
# 17       1.375338      0.090484         0.015822        0.001970
# 18       0.101376      0.015925         0.004567        0.004472
# 19       0.446829      0.062803         0.007559        0.006415
# 20       0.814858      0.028464         0.016760        0.004972
# 21       0.083883      0.010145         0.004047        0.004957
# 22       0.337710      0.031564         0.017409        0.004446
# 23       0.607006      0.037147         0.016807        0.003898
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  10
# 1    squared_error               None                  50
# 2    squared_error               None                 100
# 3    squared_error               sqrt                  10
# 4    squared_error               sqrt                  50
# 5    squared_error               sqrt                 100
# 6     friedman_mse               None                  10
# 7     friedman_mse               None                  50
# 8     friedman_mse               None                 100
# 9     friedman_mse               sqrt                  10
# 10    friedman_mse               sqrt                  50
# 11    friedman_mse               sqrt                 100
# 12  absolute_error               None                  10
# 13  absolute_error               None                  50
# 14  absolute_error               None                 100
# 15  absolute_error               sqrt                  10
# 16  absolute_error               sqrt                  50
# 17  absolute_error               sqrt                 100
# 18         poisson               None                  10
# 19         poisson               None                  50
# 20         poisson               None                 100
# 21         poisson               sqrt                  10
# 22         poisson               sqrt                  50
# 23         poisson               sqrt                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.850792
# 1   {'criterion': 'squared_error', 'max_features':...           0.860555
# 2   {'criterion': 'squared_error', 'max_features':...           0.865440
# 3   {'criterion': 'squared_error', 'max_features':...           0.830950
# 4   {'criterion': 'squared_error', 'max_features':...           0.861567
# 5   {'criterion': 'squared_error', 'max_features':...           0.865804
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.835574
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.865362
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.869200
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.845233
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.863857
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.856335
# 12  {'criterion': 'absolute_error', 'max_features'...           0.834858
# 13  {'criterion': 'absolute_error', 'max_features'...           0.846052
# 14  {'criterion': 'absolute_error', 'max_features'...           0.848239
# 15  {'criterion': 'absolute_error', 'max_features'...           0.847467
# 16  {'criterion': 'absolute_error', 'max_features'...           0.861053
# 17  {'criterion': 'absolute_error', 'max_features'...           0.858825
# 18  {'criterion': 'poisson', 'max_features': None,...           0.857743
# 19  {'criterion': 'poisson', 'max_features': None,...           0.864289
# 20  {'criterion': 'poisson', 'max_features': None,...           0.864013
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.852089
# 22  {'criterion': 'poisson', 'max_features': 'sqrt...           0.858460
# 23  {'criterion': 'poisson', 'max_features': 'sqrt...           0.855032
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.780558           0.799501           0.798791
# 1            0.758459           0.807892           0.801398
# 2            0.769019           0.809756           0.806837
# 3            0.769002           0.788117           0.806672
# 4            0.788638           0.802567           0.827425
# 5            0.786256           0.805880           0.819831
# 6            0.739412           0.807126           0.818752
# 7            0.771796           0.809963           0.805763
# 8            0.763278           0.811671           0.798232
# 9            0.791649           0.792685           0.804303
# 10           0.795228           0.807128           0.823590
# 11           0.787807           0.805412           0.825356
# 12           0.760668           0.801116           0.794358
# 13           0.776062           0.798003           0.796799
# 14           0.779463           0.792941           0.792953
# 15           0.783414           0.795585           0.813576
# 16           0.793849           0.808535           0.822319
# 17           0.789165           0.811496           0.824173
# 18           0.748451           0.804608           0.794532
# 19           0.771144           0.816579           0.806190
# 20           0.758733           0.813393           0.805647
# 21           0.759621           0.795715           0.821976
# 22           0.795517           0.807335           0.822173
# 23           0.795860           0.809286           0.829507
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.761744         0.798277        0.029693               16
# 1            0.771321         0.799925        0.035438               14
# 2            0.766566         0.803524        0.035888               11
# 3            0.758556         0.790659        0.026023               23
# 4            0.763533         0.808746        0.033543                7
# 5            0.766307         0.808816        0.033745                6
# 6            0.773520         0.794877        0.034377               21
# 7            0.767764         0.804129        0.035083               10
# 8            0.769754         0.802427        0.037847               12
# 9            0.750239         0.796822        0.030376               17
# 10           0.765794         0.811119        0.032433                3
# 11           0.766640         0.808310        0.030861                8
# 12           0.744653         0.787131        0.031719               24
# 13           0.758260         0.795035        0.029418               20
# 14           0.764459         0.795611        0.028338               19
# 15           0.739327         0.795874        0.035576               18
# 16           0.770452         0.811242        0.030257                2
# 17           0.769248         0.810581        0.030594                5
# 18           0.753424         0.791751        0.039678               22
# 19           0.771996         0.806039        0.034295                9
# 20           0.768457         0.802049        0.037379               13
# 21           0.762039         0.798288        0.035416               15
# 22           0.771600         0.811017        0.028923                4
# 23           0.768256         0.811588        0.029458                1

# %% [raw]
# age = int(input("Enter the age:"))
# bmi = float(input("Enter the BMI:"))
# children = int(input("Enter the children number:"))
# sex = int(input("Enter sex (0 for female and 1 for male):"))
# smoker = int(input("Enter 0 for non smoker and 1 for smoker:"))

# %% [raw]
# Final_prediction =grid.predict([[age,bmi,children,sex,smoker]])
# print("Final_prediction of RF: {}".format(Final_prediction))

# %%
y_pred = grid.predict(X_test)

# %%
from sklearn.metrics import r2_score #Evaluation metrics

r_score = r2_score(y_test, y_pred)
r_score
# Out:
# 0.8669379573581681

# %%
import pickle

fileName = "RF_Grid_WithSplitData_Insurance.sav"

pickle.dump(grid, open(fileName,'wb'))

# %%
load_model = pickle.load(open(fileName,'rb'))

result = load_model.predict([[30,25.899,2,1,1]])
result
# Out:
# array([47793.5675514])
